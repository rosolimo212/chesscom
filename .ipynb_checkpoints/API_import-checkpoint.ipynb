# %% [markdown]
# # Prepairing chesscom data to use

# %% [markdown]
# ## Import and functions

# %%
# coding: utf-8

# our all
import numpy as np
import pandas as pd

# usefull pandas settings
pd.set_option('display.max_rows', 45000)
pd.set_option('display.max_columns', 50000)
pd.set_option('display.max_colwidth', 5000)

# for API working and current time
import requests
import datetime

# chess pgn-reading tool
from pgn_parser import pgn, parser

# multistreaming
import threading

# отключим предупреждения Anaconda
import warnings
warnings.simplefilter('ignore')

import json
import datetime

# %%
# for logging our process
def logging(proc, par):
    import datetime
    now=datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')

    import json
    params_dict={}
    for val in par:
        params_dict.update(val)
        
    params = json.dumps(params_dict)

    log_df=pd.DataFrame([now, proc, params]).T
    log_df.columns=['time', 'proc', 'params']

    log_df.to_csv('log.csv', index=False, header=False, mode='a+')

# %%
# convert unixtime to time:
# fr_unixtime(1565211491) -> '2019-08-07 20:58:11'
def fr_unixtime(ts):
    from datetime import datetime
    return datetime.utcfromtimestamp(int(ts)).strftime('%Y-%m-%d %H:%M:%S')

# convert integer month number to string API format:
# 1 -> '01' 
# 9 -> '09' 
# 12 > '12'
# 112 -> -1
def get_number(x):
    if x>=10 and x<100:
        return str(x)
    elif x<10:
        return '0'+str(x)
    else:
        return -1
    
# retunr classoc Elo propabilities
# elo_prob(2882, 2722) -> 0.7152 (72% chanses Carlsen (2882) to beat Wan Hao (2722))
def elo_prob(rw, rb):
    return 1/(1+np.power(10, (rb-rw)/400))


# working with pgn
# pip install pgn-parser
def get_pgn(text):
    from pgn_parser import pgn, parser
    game = parser.parse(text, actions=pgn.Actions())
    
    try:
        score=game.tag_pairs['Result']
    except:
        score='Unknown'  
    try:
        date=game.tag_pairs['Date']
    except:
        date='Unknown'
    try:
        time=game.tag_pairs['UTCTime']
    except:
        time='Unknown'
    try:
        eco=game.tag_pairs['ECO']
    except:
        eco='Unknown'
    try:
        ecourl=game.tag_pairs['ECOUrl']
    except:
        ecourl='Unknown'
    return {'score':score, 
            'date': date, 
            'time':time, 
            'ECO':eco, 
            'ECO_url':ecourl}

# functions for predictions
# find col with target user (white or black)
def find_col(target_user, col1, wh_val, bl_val):
    if col1==target_user:
        return wh_val
    else:
        return bl_val
# reverse fun of find_col    
def find_opp(target_user, col1, wh_val, bl_val):
    if col1!=target_user:
        return wh_val
    else:
        return bl_val

# %%
# get json form site and return string
# exmple get_api_data_to_str('eric', '2014', '01')
def get_api_data_to_str(player, year, month):
    import requests
    response = requests.get('https://api.chess.com/pub/player/'+player+'/games/'+year+'/'+month)
    st=response.text
    
    if response.status_code ==200:
        proc='api_call_sucess'
        logging(proc, 
                [
                    {'player':player},
                    {'year': year},
                    {'month': month},
                    {'type': 'norm'}
                ]
               )
    if response.status_code !=200:
        proc='api_call_error'
        logging(proc, 
                [
                    {'player':player},
                    {'year': year},
                    {'month': month},
                    {'type': 'error'},
                    {'error_code': response.status_code},
                    {'error_message': st},
                ]
               )
    return st, response.status_code

# convert api data to pandas for next working
def get_str_data_to_pandas(strng):
    import json
    try:
        js = json.loads(strng)
        df=pd.DataFrame(js)
    except:
        proc='data_parse_error'
        logging(proc, 
                [
                    {'type': 'error'},
                    {'source': strng[0:3000]}
                ]
               )       
    return df

# convert multilevel json to table
def prepair_pandas_multilevel_data(df):
    num=len(df)
    new_df=pd.DataFrame()
    for i in range(num):
        b=pd.io.json.json_normalize(df.values[i])
        new_df=pd.concat([new_df, b])
    return new_df 

# get player games in month with preparation
def get_pl_stat(game_stat):    
    # chess result dictionary
    res_dict={
    'win': 1.0,
    'checkmated': 0.0,
    'agreed': 0.5,
    'repetition': 0.5,
    'timeout': 0.0,
    'resigned': 0.0,
    'stalemate': 0.5,
    'lose': 0.0,
    'insufficient': 0.5,
    '50move': 0.5,
    'abandoned': 0.0,
    'kingofthehill': 0.5,
    'threecheck': 0.5,
    'timevsinsufficient': 0.5,
    'bughousepartnerlose': 0.0
    }

    # number of games
    num=len(game_stat)
    
    # cut long and unusefull columns
    game_stat=game_stat[['rules', 'time_class', 'time_control', 'rated',
        'white.@id', 'white.rating', 'white.result', 'white.username',
         'black.@id', 'black.rating', 'black.result', 'black.username',
         'end_time', 'pgn', 
         'url']]
    # score 0.0, 0.5 or 1.0
    game_stat['white.score']=game_stat['white.result'].map(res_dict)
    game_stat['black.score']=game_stat['black.result'].map(res_dict)
    
    # pgn - long string
    game_stat['pgn']=game_stat['pgn'].apply(get_pgn)
    # result - string like '1-0'
    game_stat['result']=game_stat['pgn'].apply(lambda x: x['score'])
    
    game_stat['date']=game_stat['pgn'].apply(lambda x: x['date'])
    game_stat['time']=game_stat['pgn'].apply(lambda x: x['time'])
    
    # ECO - string like 'B10'
    game_stat['eco']=game_stat['pgn'].apply(lambda x: x['ECO'])
    # ECOurl - url like 'https://www.chess.com/openings/B10-Caro-Kann-Defense-2.Nf3-d5'
    game_stat['eco_url']=game_stat['pgn'].apply(lambda x: x['ECO_url'])
    
    # propability from classic formula
    game_stat['white_elo_forecast']=game_stat[['white.rating', 'black.rating']].apply(lambda x: elo_prob(*x), axis=1)
    game_stat['black_elo_forecast']=game_stat[['black.rating', 'white.rating']].apply(lambda x: elo_prob(*x), axis=1)
    
    # after it np.sum(df['game']) means number of games
    game_stat['game']=1
    game_stat['date'] = game_stat['date'].astype('datetime64[ns]')
    # period - stirng like '2019-08'
    game_stat['period']=game_stat['date'].dt.year.astype('str')+'-'+game_stat['date'].dt.month.astype('str')
        
    game_stat.columns=['rules', 'time_class', 'time_control', 'rated', 'white_url',
       'white.rating', 'white.result', 'white.username', 'black_url',
       'black.rating', 'black.result', 'black.username', 'end_time', 'pgn', 'game_url',
       'white.score', 'black.score', 'result', 'date', 'time', 'eco',
       'eco_url', 'white_elo_forecast', 'black_elo_forecast',
       'game', 'period']
    game_stat=game_stat[[
        'rules', 'time_class', 'time_control', 'rated', 'game',
        'result', 'date', 'time', 'period',
        'white.username', 'black.username',
        'white.rating', 'black.rating', 
        'white.result', 'black.result', 
        'white.score', 'black.score', 
        'white_elo_forecast', 'black_elo_forecast',
        'eco', 'eco_url', 
        'game_url', 'white_url', 'black_url'
    ]]
    
    
    game_stat['date'] = game_stat['date'].astype('datetime64[ns]')
    proc='pl_stat'
    player=game_stat['white.username'].value_counts().index[0]
    year=game_stat['date'].value_counts().index[0].strftime("%Y")
    month=game_stat['date'].value_counts().index[0].strftime("%m")
    logging(proc, 
        [
            {'player':player},
            {'year': year},
            {'month': month},
            {'type': 'norm'}
        ]
       )
    return game_stat

# %%
def status(player, year, month, status, is_error):
    import datetime
    now=datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')
    buf_df=pd.DataFrame([[player, year, month, now, status, is_error]], 
                        columns=['player', 'year', 'month', 'time','status', 'is_error'])
    buf_df.to_csv('data/status.csv', index=False, header=False, mode='a+')

# %%
# main function
def get_btch(player, year, month):
    import datetime
    import time
    import json

    status(player, year, month, 'new', is_error=0)
    
    
    # list random seconds of delay
    delay_lst=[np.round(1*np.random.rand(1,1)[0,0],0), 
               np.round(5*np.random.rand(1,1)[0,0],0), 
               np.round(100*np.random.rand(1,1)[0,0],0), ]
    
    # we give 3 attemps to get data
    for cs in range(3):    
        time.sleep(delay_lst[cs])
        # working with propably exception
        try:
            # API -> string
            data_string, code=get_api_data_to_str(player, year, month)
        except:
            data_string=''
            code=500
        # after it we need to check status code
        # case best variant
        if code==200:
            proc='api_call_saved'
            logging(proc, 
                    [
                        {'player':player},
                        {'year': year},
                        {'month': month},
                        {'type': 'norm'}
                    ]
                   )
            # exit from cicle 
            break
        # else log and try again
        else:
            api_error_str='api error, code: '+str(code)+', message: '+data_string[0:3000]+'case: '+str(cs)
            status(player, year, month, api_error_str, is_error=1)
            proc='api_call_error_recieved'
            logging(proc, 
                    [
                        {'player':player},
                        {'year': year},
                        {'month': month},
                        {'type': 'error'},
                        {'try':cs},
                        {'error_code': code},
                        {'error_message': data_string[0:3000]}
                    ]
                   ) 
        # at the end we need to log the end of our attepts
        if cs==2:
            proc='api_call_final_error'
            logging(proc, 
                    [
                        {'player':player},
                        {'year': year},
                        {'month': month},
                        {'type': 'error'},
                        {'try':cs},
                        {'error_code': code},
                        {'error_message': data_string[0:3000]}
                    ]
                   )
    
    # string -> json -> DataFrame
    try:
        multidata=get_str_data_to_pandas(data_string)
    except:
        status(player, year, month, 'error_to_pandas', is_error=1)
    
    # DataFrame -> use json normalise -> good df
    try:
        usefull_data=prepair_pandas_multilevel_data(multidata)
    except:
        status(player, year, month, 'multilevel error', is_error=1)
    
    # game prepair
    try:
        workng_data=get_pl_stat(usefull_data)
    except:
        status(player, year, month, 'coverting error', is_error=1)
    
    # save to file
    try:
        now=datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        workng_data.to_csv('source/'+player+'_'+year+'_'+month+'_'+now+'.csv')
        suc_str='successfull get data: '+str(len(workng_data))+' rows'
        status(player, year, month, suc_str, is_error=0)
    except:
        status(player, year, month, 'writing error', is_error=1)
        
    return multidata

# %%
# start getting with threading magic
def user_parse(user_list, year_range):   
    import threading
    import json
    
    i=0
    for user in user_list:
        for year in year_range:
            for month in range(1,13):
                t = threading.Thread(target=get_btch, args=(user, str(year), get_number(month)))
                t.start()
                

                i=i+1
    print('All btch', i,  'are started')

# %%
# read all json in folder and concate DataFrame
def read_files(path):
    # reading
    l=[]
    cntr=0
    import os
    for root, dirs, files in os.walk(path):
        for file in files:
            if file.endswith(".csv"):
                 l.append(os.path.join(root, file))
            cntr=cntr+1
    print('Total', cntr, 'files founded')

    # merging
    i=0
    df=pd.DataFrame()
    for link in l:
        try:
            dfb=pd.read_csv(link)
        except:
            dfb=pd.DataFrame()
        df=pd.concat([df, dfb])
        
    df=df.drop_duplicates()
    return df

# %%
# data for predict current user
def learn_prepair(df, target_user):
    df=df[(df['white.username']==target_user)|(df['black.username']==target_user)]
    df['target_user']=target_user
    df['score']=df[['target_user', 'white.username', 'white.score', 'black.score']].apply(lambda x: find_col(*x), axis=1)
    df['rating']=df[['target_user','white.username', 'white.rating', 'black.rating']].apply(lambda x: find_col(*x), axis=1)
    df['opponent_rating']=df[['target_user', 'white.username', 'white.rating', 'black.rating']].apply(lambda x: find_opp(*x), axis=1)
    df['base_elo_forec']=df[['target_user', 'white.username', 'white_elo_forecast', 'black_elo_forecast']].apply(lambda x: find_col(*x), axis=1)
    df['color']=np.where(df['white.username']==target_user, 'w', 'b')
    
    df['date'] = df['date'].astype('datetime64[ns]')
    df['year']=df['date'].dt.year
    df['month']=df['date'].dt.month
    
    return df

# %%
# get players list by countries
def get_county_players_list(country):
    import requests
    response = requests.get('https://api.chess.com/pub/country/'+country+'/players')
    st=response.text
    if response.status_code !=200:
        print(response.status_code)
        print(st[0:3000])
        
    import datetime
    now=datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')
 
    try:
        file = open('player_lists/players_list_'+country+'_'+now+'.json','w') 
        file.write(st)
        file.close()
    except Exception:
        error_st=response.status_code+st[0:3000]
        file = open('player_lists/players_list_'+country+'_'+now+'.json','w') 
        file.write( error_st)
        file.close()

# %%
def save_data(player, year, month):
    data_string, code=get_api_data_to_str(player, year, month)
    
    with open('data/'+str(player)+'_'+str(year)+'_'+str(month)+'.json', 'w') as outfile:
        json.dump(data_string, outfile)
        
    import datetime
    now=datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')
    
    status_string=str(player)+';'+str(year)+';'+str(month)+';'+str(now)+';'+str(code)+';'+data_string[0:180]
    text_file = open('log/'+str(player)+'_'+str(year)+'_'+str(month)+'.csv', 'w')
    text_file.write(status_string)
    text_file.close()

# %%
# %%time
user_list=['Rosolimo', 'Akash22', 'smcwhtdtmc']
year_range=range(2002,2004)

for user in user_list:
    print('Loading of games from user ', user, ' started')
    for year in year_range:
        print('Year ', year, ' is beginning')
        for month in range(1,13):
            now=datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')
            print(now, ' : month ', month, ' started')
            save_data(user,str(year), get_number(month))
# Out:
# Loading of games from user  Rosolimo  started
# Year  2002  is beginning
# 2020-01-12 23:23:54  : month  1  started
# 2020-01-12 23:23:54  : month  2  started
# 2020-01-12 23:23:55  : month  3  started
# 2020-01-12 23:23:56  : month  4  started
# 2020-01-12 23:23:56  : month  5  started
# 2020-01-12 23:23:57  : month  6  started
# 2020-01-12 23:23:58  : month  7  started

onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]

log_df=pd.DataFrame()
b=pd.DataFrame()
for file in onlyfiles:
    b=pd.read_csv('log/'+file, header=None, sep=';')
    log_df=pd.concat([log_df, b])
    
log_df.columns=['user', 'year', 'month', 'last_update_time', 'code', 'caption']

# %%
log_df[0:3]
# Out:
#          user  year  month     last_update_time  code  \
# 0    Rosolimo  2016      3  2020-01-12 23:00:00   200
# 0  smcwhtdtmc  2003     10  2020-01-12 23:24:44   200
# 0     Akash22  2012      8  2020-01-12 23:02:39   200
#
#                                                                                                                                                                                 caption
# 0  {"games":[{"url":"https://www.chess.com/live/game/1483476516","pgn":"[Event \"Live Chess\"]\n[Site \"Chess.com\"]\n[Date \"2016.03.02\"]\n[Round \"-\"]\n[White \"Rosolimo\"]\n[Blac
# 0                                                                                                                                                                          {"games":[]}
# 0                                                                                                                                                                          {"games":[]}

# %%
log_df['is_games']=np.where(log_df['caption']=='{"games":[]}',0,1)
log_df=log_df.reset_index()
log_df['buf']=log_df.index
log_df.groupby(['code', 'is_games']).agg({'buf': lambda x: x.nunique()}).reset_index()
# Out:
#    code  is_games  buf
# 0   200         0  227
# 1   200         1  136
# 2   404         1   33

# %%
log_df[log_df['user']=='Rosolimo'].sort_values(by=['year','month'])
# Out:
#      index      user  year  month     last_update_time  code  \
# 285      0  Rosolimo  2002      1  2020-01-12 23:23:54   200
# 370      0  Rosolimo  2002      2  2020-01-12 23:23:55   200
# 387      0  Rosolimo  2002      3  2020-01-12 23:23:56   200
# 270      0  Rosolimo  2002      4  2020-01-12 23:23:56   200
# 108      0  Rosolimo  2002      5  2020-01-12 23:23:57   200
# 369      0  Rosolimo  2002      6  2020-01-12 23:23:58   200
# 352      0  Rosolimo  2002      7  2020-01-12 23:23:59   200
# 364      0  Rosolimo  2002      8  2020-01-12 23:24:00   200
# 361      0  Rosolimo  2002      9  2020-01-12 23:24:00   200
# 308      0  Rosolimo  2002     10  2020-01-12 23:24:01   200
# 103      0  Rosolimo  2002     11  2020-01-12 23:24:02   200
# 75       0  Rosolimo  2002     12  2020-01-12 23:24:03   200
# 65       0  Rosolimo  2003      1  2020-01-12 23:24:04   200
# 355      0  Rosolimo  2003      2  2020-01-12 23:24:05   200
# 227      0  Rosolimo  2003      3  2020-01-12 23:24:06   200
# 13       0  Rosolimo  2003      4  2020-01-12 23:24:06   200
# 167      0  Rosolimo  2003      5  2020-01-12 23:24:07   200
# 178      0  Rosolimo  2003      6  2020-01-12 23:24:08   200
# 146      0  Rosolimo  2003      7  2020-01-12 23:24:09   200
# 9        0  Rosolimo  2003      8  2020-01-12 23:24:10   200
# 118      0  Rosolimo  2003      9  2020-01-12 23:24:10   200
# 125      0  Rosolimo  2003     10  2020-01-12 23:24:12   200
# 389      0  Rosolimo  2003     11  2020-01-12 23:24:12   200
# 57       0  Rosolimo  2003     12  2020-01-12 23:24:13   200
# 137      0  Rosolimo  2012      1  2020-01-12 22:57:07   200
# 298      0  Rosolimo  2012      2  2020-01-12 22:57:08   200
pgn":"[Event \"Live Chess\"]\n[Site \"Chess.com\"]\n[Date \"2018.08.02\"]\n[Round \"-\"]\n[White \"Disidentes\"]\n[Bl
# 378  {"games":[{"url":"https://www.chess.com/live/game/3045393892","pgn":"[Event \"Live Chess\"]\n[Site \"Chess.com\"]\n[Date \"2018.09.01\"]\n[Round \"-\"]\n[White \"Vasylii\"]\n[Black
# 104  {"games":[{"url":"https://www.chess.com/live/game/3113119422","pgn":"[Event \"Live Chess\"]\n[Site \"Chess.com\"]\n[Date \"2018.10.01\"]\n[Round \"-\"]\n[White \"comicpawn\"]\n[Bla
# 287  {"games":[{"url":"https://www.chess.com/live/game/3184723118","pgn":"[Event \"Live Chess\"]\n[Site \"Chess.com\"]\n[Date \"2018.11.01\"]\n[Round \"-\"]\n[White \"tudoras\"]\n[Black
# 87   {"games":[{"url":"https://www.chess.com/live/game/3258551241","pgn":"[Event \"Live Chess\"]\n[Site \"Chess.com\"]\n[Date \"2018.12.01\"]\n[Round \"-\"]\n[White \"Peryman\"]\n[Black
# 344  {"games":[{"url":"https://www.chess.com/live/game/3340235459","pgn":"[Event \"Live Chess\"]\n[Site \"Chess.com\"]\n[Date \"2019.01.01\"]\n[Round \"-\"]\n[White \"Rosolimo\"]\n[Blac
# 341  {"games":[{"url":"https://www.chess.com/live/game/3425962561","pgn":"[Event \"Live Chess\"]\n[Site \"Chess.com\"]\n[Date \"2019.02.02\"]\n[Round \"-\"]\n[White \"Rosolimo\"]\n[Blac
# 313  {"games":[{"url":"https://www.chess.com/live/game/3498740995","pgn":"[Event \"Live Chess\"]\n[Site \"Chess.com\"]\n[Date \"2019.03.01\"]\n[Round \"-\"]\n[White \"Rosolimo\"]\n[Blac
# 37   {"games":[{"url":"https://www.chess.com/live/game/3581194264","pgn":"[Event \"Live Chess\"]\n[Site \"Chess.com\"]\n[Date \"2019.04.01\"]\n[Round \"-\"]\n[White \"Rosolimo\"]\n[Blac
# 186  {"games":[{"url":"https://www.chess.com/live/game/3670320271","pgn":"[Event \"Live Chess\"]\n[Site \"Chess.com\"]\n[Date \"2019.05.04\"]\n[Round \"-\"]\n[White \"fredinfowarrior\"]
# 5    {"games":[{"url":"https://www.chess.com/live/game/3746967104","pgn":"[Event \"Live Chess\"]\n[Site \"Chess.com\"]\n[Date \"2019.06.01\"]\n[Round \"-\"]\n[White \"Rosolimo\"]\n[Blac
# 107  {"games":[{"url":"https://www.chess.com/live/game/3838347080","pgn":"[Event \"Live Chess\"]\n[Site \"Chess.com\"]\n[Date \"2019.07.05\"]\n[Round \"-\"]\n[White \"Rosolimo\"]\n[Blac
# 93   {"games":[{"url":"https://www.chess.com/live/game/3911784040","pgn":"[Event \"Live Chess\"]\n[Site \"Chess.com\"]\n[Date \"2019.08.01\"]\n[Round \"-\"]\n[White \"camxha\"]\n[Black
# 160  {"games":[{"url":"https://www.chess.com/live/game/3995898254","pgn":"[Event \"Live Chess\"]\n[Site \"Chess.com\"]\n[Date \"2019.09.01\"]\n[Round \"-\"]\n[White \"Rosolimo\"]\n[Blac
# 384  {"games":[{"url":"https://www.chess.com/live/game/4084519977","pgn":"[Event \"Live Chess\"]\n[Site \"Chess.com\"]\n[Date \"2019.10.02\"]\n[Round \"-\"]\n[White \"Akash22\"]\n[Black
# 16   {"games":[{"url":"https://www.chess.com/live/game/4172991759","pgn":"[Event \"Live Chess\"]\n[Site \"Chess.com\"]\n[Date \"2019.11.02\"]\n[Round \"-\"]\n[White \"humbertilio\"]\n[B
# 46   {"games":[{"url":"https://www.chess.com/live/game/4265049830","pgn":"[Event \"Live Chess\"]\n[Site \"Chess.com\"]\n[Date \"2019.12.03\"]\n[Round \"-\"]\n[White \"Sureshvishwa\"]\n[
# 49   {"games":[{"url":"https://www.chess.com/live/game/4355698990","pgn":"[Event \"Live Chess\"]\n[Site \"Chess.com\"]\n[Date \"2020.01.01\"]\n[Round \"-\"]\n[White \"Rosolimo\"]\n[Blac
# 241                                                                                                                               {"message":"Date cannot be set in the future","code":0}
# 68                                                                                                                                {"message":"Date cannot be set in the future","code":0}
# 58                                                                                                                                {"message":"Date cannot be set in the future","code":0}
# 134                                                                                                                               {"message":"Date cannot be set in the future","code":0}
# 116                                                                                                                               {"message":"Date cannot be set in the future","code":0}
# 174                                                                                                                               {"message":"Date cannot be set in the future","code":0}
# 385                                                                                                                               {"message":"Date cannot be set in the future","code":0}
# 64                                                                                                                                {"message":"Date cannot be set in the future","code":0}
# 195                                                                                                                               {"message":"Date cannot be set in the future","code":0}
# 382                                                                                                                               {"message":"Date cannot be set in the future","code":0}
# 170                                                                                                                               {"message":"Date cannot be set in the future","code":0}
#
#      is_games  buf
# 285         0  285
# 370         0  370
# 387         0  387
# 270         0  270
# 108         0  108
# 369         0  369
# 352         0  352
# 364         0  364
# 361         0  361
# 308         0  308
# 103         0  103
# 75          0   75
# 65          0   65
# 355         0  355
# 227         0  227
# 13          0   13
# 167         0  167
# 178         0  178
# 146         0  146
# 9           0    9
# 118         0  118
# 125         0  125
# 389         0  389
# 57          0   57
# 137         0  137
# 298         0  298
# 286         0  286
# 53          0   53
# 55          0   55
# 33          0   33
# 307         0  307
# 304         0  304
# 237         1  237
# 258         0  258
# 338         0  338
# 383         0  383
# 239         0  239
# 141         0  141
# 138         0  138
# 263         0  263
# 219         0  219
# 235         0  235
# 294         0  294
# 343         0  343
# 131         1  131
# 120         1  120
# 259         1  259
# 228         1  228
# 36          1   36
# 353         1  353
# 221         1  221
# 81          1   81
# 122         1  122
# 311         1  311
# 212         1  212
# 60          1   60
# 176         1  176
# 257         1  257
# 63          1   63
# 88          1   88
# 278         1  278
# 89          1   89
# 367         1  367
# 249         1  249
# 289         1  289
# 190         1  190
# 180         1  180
# 24          1   24
# 303         1  303
# 181         1  181
# 148         1  148
# 23          1   23
# 194         1  194
# 169         1  169
# 0           1    0
# 15          1   15
# 203         1  203
# 34          1   34
# 150         1  150
# 292         1  292
# 256         1  256
# 193         1  193
# 164         1  164
# 350         1  350
# 246         1  246
# 388         1  388
# 6           1    6
# 275         1  275
# 45          1   45
# 314         1  314
# 86          1   86
# 254         1  254
# 319         1  319
# 290         1  290
# 70          1   70
# 94          1   94
# 204         1  204
# 269         1  269
# 111         1  111
# 358         1  358
# 3           1    3
# 251         1  251
# 380         1  380
# 230         1  230
# 378         1  378
# 104         1  104
# 287         1  287
# 87          1   87
# 344         1  344
# 341         1  341
# 313         1  313
# 37          1   37
# 186         1  186
# 5           1    5
# 107         1  107
# 93          1   93
# 160         1  160
# 384         1  384
# 16          1   16
# 46          1   46
# 49          1   49
# 241         1  241
# 68          1   68
# 58          1   58
# 134         1  134
# 116         1  116
# 174         1  174
# 385         1  385
# 64          1   64
# 195         1  195
# 382         1  382
# 170         1  170

# %%
def load_games(file):
    with open(file) as json_file:
        jsf = json.load(json_file)
    jss = json.loads(jsf)
    first_df=pd.DataFrame(jss)
    
    game_stat=prepair_pandas_multilevel_data(first_df)
    res=get_pl_stat(game_stat)
    
    return res

# %%
df=load_games('data/Rosolimo_2016_10.json')

# %%
len(df)
# Out:
# 206

# %%
df[0:10]
# Out:
#    rules time_class time_control  rated  game result       date      time  \
# 0  chess      blitz        180+2   True     1    0-1 2016-10-02  15:55:28
# 0  chess      blitz        180+2   True     1    1-0 2016-10-02  16:06:41
# 0  chess      blitz        180+2   True     1    1-0 2016-10-02  16:17:53
# 0  chess      blitz        180+2   True     1    0-1 2016-10-02  16:24:11
# 0  chess      blitz        180+2   True     1    1-0 2016-10-02  19:40:48
# 0  chess      blitz        180+2   True     1    1-0 2016-10-02  19:53:07
# 0  chess      blitz        180+2   True     1    1-0 2016-10-02  19:55:14
# 0  chess      blitz        180+2   True     1    1-0 2016-10-02  19:59:28
# 0  chess      blitz        180+2   True     1    1-0 2016-10-02  20:04:08
# 0  chess      blitz        180+2   True     1    1-0 2016-10-02  20:13:00
#
#     period  white.username black.username  white.rating  black.rating  \
# 0  2016-10      mccorrao27       Rosolimo          1559          1595
# 0  2016-10        Rosolimo   swapnil_5486          1602          1560
# 0  2016-10        Rosolimo   BFishIsMyFav          1608          1504
# 0  2016-10        Rosolimo        amw1212          1600          1613
# 0  2016-10          owenly       Rosolimo          1538          1590
# 0  2016-10        Rosolimo      wbabayeju          1598          1573
# 0  2016-10  Dr_Octagonapus       Rosolimo          1598          1590
# 0  2016-10        penullar       Rosolimo          1698          1584
# 0  2016-10        Rosolimo       penullar          1595          1687
# 0  2016-10        Rosolimo         jrmele          1602          1528
#
#   white.result black.result  white.score  black.score  white_elo_forecast  \
# 0      timeout          win          0.0          1.0            0.448376
# 0          win     resigned          1.0          0.0            0.560150
# 0          win     resigned          1.0          0.0            0.645352
# 0    abandoned          win          0.0          1.0            0.481300
# 0          win     resigned          1.0          0.0            0.425720
# 0          win   checkmated          1.0          0.0            0.535916
# 0          win   checkmated          1.0          0.0            0.511511
# 0          win     resigned          1.0          0.0            0.658415
# 0          win      timeout          1.0          0.0            0.370611
# 0          win      timeout          1.0          0.0            0.604913
#
#    black_elo_forecast  eco  \
# 0            0.551624  B13
# 0            0.439850  A16
# 0            0.354648  E00
# 0            0.518700  D30
# 0            0.574280  B10
# 0            0.464084  D35
# 0            0.488489  B13
# 0            0.341585  A45
# 0            0.629389  D08
# 0            0.395087  D43
#
#                                                                                                 eco_url  \
# 0                https://www.chess.com/openings/Caro-Kann-Defense-Exchange-Variation-3...cxd5-4.Nf3-Nf6
# 0  https://www.chess.com/openings/English-Opening-Anglo-Indian-Queens-Knight-Variation-2...g6-3.Nf3-Bg7
# 0                                        https://www.chess.com/openings/Indian-Game-East-Indian-Defense
# 0                                                 https://www.chess.com/openings/Queens-Gambit-Declined
# 0                                             https://www.chess.com/openings/Caro-Kann-Defense-2.Nf3-d5
# 0                 https://www.chess.com/openings/Queens-Gambit-Declined-Queens-Knight-Variation-3...Nf6
# 0                          https://www.chess.com/openings/Caro-Kann-Defense-Exchange-Variation-3...cxd5
# 0                                                      https://www.chess.com/openings/Indian-Game-2.Nc3
# 0         https://www.chess.com/openings/Queens-Gambit-Declined-Albin-Countergambit-3.dxe5-d4-4.Nf3-Nc6
# 0                                                      https://www.chess.com/openings/Semi-Slav-Defense
#
#                                      game_url  \
# 0  https://www.chess.com/live/game/1752363107
# 0  https://www.chess.com/live/game/1752375472
# 0  https://www.chess.com/live/game/1752388091
# 0  https://www.chess.com/live/game/1752395497
# 0  https://www.chess.com/live/game/1752626228
# 0  https://www.chess.com/live/game/1752640347
# 0  https://www.chess.com/live/game/1752642703
# 0  https://www.chess.com/live/game/1752647396
# 0  https://www.chess.com/live/game/1752652676
# 0  https://www.chess.com/live/game/1752662455
#
#                                          white_url  \
# 0      https://api.chess.com/pub/player/mccorrao27
# 0        https://api.chess.com/pub/player/rosolimo
# 0        https://api.chess.com/pub/player/rosolimo
# 0        https://api.chess.com/pub/player/rosolimo
# 0          https://api.chess.com/pub/player/owenly
# 0        https://api.chess.com/pub/player/rosolimo
# 0  https://api.chess.com/pub/player/dr_octagonapus
# 0        https://api.chess.com/pub/player/penullar
# 0        https://api.chess.com/pub/player/rosolimo
# 0        https://api.chess.com/pub/player/rosolimo
#
#                                        black_url
# 0      https://api.chess.com/pub/player/rosolimo
# 0  https://api.chess.com/pub/player/swapnil_5486
# 0  https://api.chess.com/pub/player/bfishismyfav
# 0       https://api.chess.com/pub/player/amw1212
# 0      https://api.chess.com/pub/player/rosolimo
# 0     https://api.chess.com/pub/player/wbabayeju
# 0      https://api.chess.com/pub/player/rosolimo
# 0      https://api.chess.com/pub/player/rosolimo
# 0      https://api.chess.com/pub/player/penullar
# 0        https://api.chess.com/pub/player/jrmele

# %%
jl;l;
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-177-d5b22e5736be> in <module>
# ----> 1 jl;l;
#
# NameError: name 'jl' is not defined

# %%
data_string, code=get_api_data_to_str('rosolimo','2004', '10')
# b_df=get_str_data_to_pandas(data_string)
# game_stat=prepair_pandas_multilevel_data(b_df)
# res=get_pl_stat(game_stat)

# %%
user_list=['Rosolimo', 'Akash22', 'smcwhtdtmc']
year_range=range(2012,2014)

state=pd.DataFrame(columns=['user', 'year', 'month'])
u_lst=[]
y_lst=[]
m_lst=[]
for user in user_list:
    for year in year_range:
        for month in range(1,13):
            u_lst.append(user)
            y_lst.append(str(year))
            m_lst.append(get_number(month))
            
state['user']=u_lst
state['year']=y_lst
state['month']=m_lst

state['final_status']='not ready'
# final_status: not ready, ready
state['status']='not started'
# status: not started, uploaded, converted to pandas, get multilevel, ready
# eror status: not uploaded, not converted to pandas, not get multilevel, not get player stat, other errors

# %%
state['final_status']=np.where(state['status']=='ready', 'ready', 'not_ready')
state['status']=np.where(
            (state['user']==status_string[0])&
            (state['year']==status_string[1])&
            (state['month']==status_string[2]), status_string[3], state['status']
                        )

# %%
state
# Out:
#           user  year month final_status       status
# 0     Rosolimo  2012    01    not_ready  not started
# 1     Rosolimo  2012    02    not_ready  not started
# 2     Rosolimo  2012    03    not_ready  not started
# 3     Rosolimo  2012    04    not_ready  not started
# 4     Rosolimo  2012    05    not_ready  not started
# 5     Rosolimo  2012    06    not_ready  not started
# 6     Rosolimo  2012    07    not_ready  not started
# 7     Rosolimo  2012    08    not_ready  not started
# 8     Rosolimo  2012    09    not_ready  not started
# 9     Rosolimo  2012    10    not_ready  not started
# 10    Rosolimo  2012    11    not_ready  not started
# 11    Rosolimo  2012    12    not_ready  not started
# 12    Rosolimo  2013    01    not_ready  not started
# 13    Rosolimo  2013    02    not_ready  not started
# 14    Rosolimo  2013    03    not_ready  not started
# 15    Rosolimo  2013    04    not_ready  not started
# 16    Rosolimo  2013    05    not_ready  not started
# 17    Rosolimo  2013    06    not_ready  not started
# 18    Rosolimo  2013    07    not_ready  not started
# 19    Rosolimo  2013    08    not_ready  not started
# 20    Rosolimo  2013    09    not_ready  not started
# 21    Rosolimo  2013    10    not_ready  not started
# 22    Rosolimo  2013    11    not_ready  not started
# 23    Rosolimo  2013    12    not_ready  not started
# 24     Akash22  2012    01    not_ready  not started
# 25     Akash22  2012    02    not_ready  not started
# 26     Akash22  2012    03    not_ready  not started
# 27     Akash22  2012    04    not_ready  not started
# 28     Akash22  2012    05    not_ready  not started
# 29     Akash22  2012    06    not_ready  not started
# 30     Akash22  2012    07    not_ready  not started
# 31     Akash22  2012    08    not_ready  not started
# 32     Akash22  2012    09    not_ready  not started
# 33     Akash22  2012    10    not_ready  not started
# 34     Akash22  2012    11    not_ready  not started
# 35     Akash22  2012    12    not_ready  not started
# 36     Akash22  2013    01    not_ready  not started
# 37     Akash22  2013    02    not_ready  not started
# 38     Akash22  2013    03    not_ready  not started
# 39     Akash22  2013    04    not_ready  not started
# 40     Akash22  2013    05    not_ready  not started
# 41     Akash22  2013    06    not_ready  not started
# 42     Akash22  2013    07    not_ready  not started
# 43     Akash22  2013    08    not_ready  not started
# 44     Akash22  2013    09    not_ready  not started
# 45     Akash22  2013    10    not_ready  not started
# 46     Akash22  2013    11    not_ready  not started
# 47     Akash22  2013    12    not_ready  not started
# 48  smcwhtdtmc  2012    01    not_ready  not started
# 49  smcwhtdtmc  2012    02    not_ready  not started
# 50  smcwhtdtmc  2012    03    not_ready  not started
# 51  smcwhtdtmc  2012    04    not_ready  not started
# 52  smcwhtdtmc  2012    05    not_ready  not started
# 53  smcwhtdtmc  2012    06    not_ready  not started
# 54  smcwhtdtmc  2012    07    not_ready  not started
# 55  smcwhtdtmc  2012    08    not_ready  not started
# 56  smcwhtdtmc  2012    09    not_ready  not started
# 57  smcwhtdtmc  2012    10    not_ready  not started
# 58  smcwhtdtmc  2012    11    not_ready  not started
# 59  smcwhtdtmc  2012    12    not_ready  not started
# 60  smcwhtdtmc  2013    01    not_ready  not started
# 61  smcwhtdtmc  2013    02    not_ready  not started
# 62  smcwhtdtmc  2013    03    not_ready  not started
# 63  smcwhtdtmc  2013    04    not_ready  not started
# 64  smcwhtdtmc  2013    05    not_ready  not started
# 65  smcwhtdtmc  2013    06    not_ready  not started
# 66  smcwhtdtmc  2013    07    not_ready  not started
# 67  smcwhtdtmc  2013    08    not_ready  not started
# 68  smcwhtdtmc  2013    09    not_ready  not started
# 69  smcwhtdtmc  2013    10    not_ready  not started
# 70  smcwhtdtmc  2013    11    not_ready  not started
# 71  smcwhtdtmc  2013    12    not_ready  not started

# %%
def load_proces(player, year, month):
    final_status='not ready'
    status='not started'
    
    res=pd.DataFrame()
    
    try:
        data_string, code=get_api_data_to_str(player, year, month)
        status='uploaded'
    except:
        status='uploaded'
        return res, status
    
    try:
        b_df=get_str_data_to_pandas(data_string)
        status='converted to pandas'
    except:
        status='not converted to pandas'
        return res, status
    
    try:
        game_stat=prepair_pandas_multilevel_data(b_df)
        status='get multilevel'
    except:
        status='not get multilevel'
        return res, status
    
    try:
        res=get_pl_stat(game_stat)
        status='ready'
    except:
        status='not get player stat'
        return res, status
    
    
    return res, status

# %%
# %%time
res, status=load_proces('Rosolimo','2020', '01')
# status_string=['Rosolimo','2009', '11', status]
# Out:
# CPU times: user 2.49 s, sys: 11.4 ms, total: 2.5 s
# Wall time: 5.65 s

# %%
# %%time
data_string, code=get_api_data_to_str('Rosolimo','2020', '01')
# Out:
# CPU times: user 37.6 ms, sys: 82 µs, total: 37.7 ms
# Wall time: 249 ms

# %%
type(data_string)
# Out:
# str

# %%
status_string[3]
# Out:
# 'ready'

# %%
res[0:3]
# Out:
#    rules time_class time_control  rated  game   result       date      time  \
# 0  chess      blitz        180+2   True     1      1-0 2020-01-01  13:06:14
# 0  chess      blitz        180+2   True     1      1-0 2020-01-01  13:16:38
# 0  chess      blitz        180+2   True     1  1/2-1/2 2020-01-02  11:36:59
#
#    period white.username black.username  white.rating  black.rating  \
# 0  2020-1       Rosolimo    Viiktor3112          1558          1540
# 0  2020-1       Rosolimo      supernemm          1565          1489
# 0  2020-1       Rosolimo    jean-arnaud          1564          1533
#
#   white.result black.result  white.score  black.score  white_elo_forecast  \
# 0          win      timeout          1.0          0.0            0.525881
# 0          win     resigned          1.0          0.0            0.607661
# 0    stalemate    stalemate          0.5          0.5            0.544495
#
#    black_elo_forecast  eco  \
# 0            0.474119  A65
# 0            0.392339  D10
# 0            0.455505  D10
#
#                                                                        eco_url  \
# 0  https://www.chess.com/openings/Benoni-Defense-Modern-Kings-Pawn-Line-6...g6
# 0                            https://www.chess.com/openings/Slav-Defense-3.Nc3
# 0                            https://www.chess.com/openings/Slav-Defense-3.Nc3
#
#                                      game_url  \
# 0  https://www.chess.com/live/game/4355698990
# 0  https://www.chess.com/live/game/4355721234
# 0  https://www.chess.com/live/game/4358666000
#
#                                    white_url  \
# 0  https://api.chess.com/pub/player/rosolimo
# 0  https://api.chess.com/pub/player/rosolimo
# 0  https://api.chess.com/pub/player/rosolimo
#
#                                       black_url
# 0  https://api.chess.com/pub/player/viiktor3112
# 0    https://api.chess.com/pub/player/supernemm
# 0  https://api.chess.com/pub/player/jean-arnaud

# %%
len(res)
# Out:
# 81

# %%
get_btch('rosolimo','2019', '10')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-231-1b7429f6635b> in <module>
# ----> 1 get_btch('rosolimo','2019', '10')
#
# <ipython-input-226-91bda369dd34> in get_btch(player, year, month)
#      15     # we give 3 attemps to get data
#      16     for cs in range(3):
# ---> 17         time.sleep(delay_lst[cs])
#      18         # working with propably exception
#      19         try:
#
# KeyboardInterrupt:

# %%
df=pd.read_csv('data/status.csv', header=None)
df.columns=['player', 'year', 'month', 'time','status', 'is_error']
df['batch']=df['player']+'-'+df['year'].astype('str')+'-'+df['month'].astype('str')
df['is_429']=np.where(df['status']=='api error, code: 429, message: case: 2',1,0)

# %%
len(df)
# Out:
# 4032

# %%
df.sample(3)
# Out:
#       player  year  month                 time  \
# 721   031222  2018      9  2019-09-01 21:55:38
# 1188  05adam  2018     10  2019-09-01 21:55:44
# 364     0899  2018      1  2019-09-01 21:55:29
#
#                                       status  is_error           batch  is_429
# 721   api error, code: 429, message: case: 0         1   031222-2018-9       0
# 1188  api error, code: 429, message: case: 0         1  05adam-2018-10       0
# 364                                      new         0     0899-2018-1       0

# %%
total_case=df[df['status']=='new'].groupby(['batch', 'player', 'year', 'month']).min()[['time']].reset_index()
error_case=df[df['is_error']==1].groupby(['batch']).min()[['status', 'time']].reset_index()
suc_case=df[(df['is_error']==0)&(df['status']!='new')].groupby(['batch']).max()[['status', 'time']].reset_index()
api_errors=df[df['is_429']==1][['batch']].drop_duplicates()

# %%
api_errors.sample(3)
# Out:
#                batch
# 3359  090124-2019-12
# 3618   090124-2019-3
# 2463     0865-2018-7

# %%
suc_case['is_sucsessfull']=1
api_errors['is_429']=1
suc_case=suc_case[['batch', 'is_sucsessfull']]
loading_result=total_case.merge(suc_case, 'left', on=['batch']).fillna(0)
loading_result=loading_result.merge(api_errors, 'left', on=['batch']).fillna(0)

# %%
loading_result.sample(3)
# Out:
#                    batch       player  year  month                 time  \
# 702      0neghost-2018-4     0neghost  2018      4  2019-09-01 21:55:31
# 614  0emptiness0-2019-11  0emptiness0  2019     11  2019-09-01 21:55:31
# 650      0lebull-2018-11      0lebull  2018     11  2019-09-01 21:55:31
#
#      is_sucsessfull  is_429
# 702             0.0     0.0
# 614             0.0     0.0
# 650             0.0     1.0

# %%
loading_result.groupby(['is_sucsessfull', 'is_429']).agg({'batch': lambda x: x.nunique()})
# Out:
#                        batch
# is_sucsessfull is_429
# 0.0            0.0       346
#                1.0       212
# 1.0            0.0       162

# %%
df[df['batch']=='02_qeka_02-2018-7']
# Out:
#           player  year  month                 time  \
# 1035  02_qeka_02  2018      7  2019-09-01 18:33:19
# 1408  02_qeka_02  2018      7  2019-09-01 18:33:31
# 2824  02_qeka_02  2018      7  2019-09-01 18:33:46
# 4293  02_qeka_02  2018      7  2019-09-01 18:34:23
# 4426  02_qeka_02  2018      7  2019-09-01 18:34:23
#
#                                       status  is_error              batch
# 1035                                     new         0  02_qeka_02-2018-7
# 1408  api error, code: 429, message: case: 0         1  02_qeka_02-2018-7
# 2824  api error, code: 429, message: case: 1         1  02_qeka_02-2018-7
# 4293                         coverting error         1  02_qeka_02-2018-7
# 4426                           writing error         1  02_qeka_02-2018-7

# %%
get_api_data_to_str('02_qeka_02', '2018', '07')
# Out:
# ('{"games":[]}', 200)

# %% [markdown]
# ## Start working

# %%
# collect players by countries
# countries_list=['RU']
# get_county_players_list(countries_list[0])

user_list=pd.read_json('player_lists/players_list_RU_2019-08-25 10:47:56.json')['players'].values
# user_list=['andreyvict', 'sever043', 'Rosolimo']

# %%
user_list[30:60]
# Out:
# array(['031222', '04101981', '05031969', '05adam', '05djabrail05',
#        '05omar05', '061074', '0647634', '071110', '0712chains',
#        '07egor93', '07w1', '0812bsa', '08626', '0865', '0899', '08srg08',
#        '090124', '091321', '09tigr09', '09vrw', '0aba', '0artmak0',
#        '0blizzard', '0coldlikedeath0', '0emptiness0', '0l0j', '0lebull',
#        '0mikki', '0neghost'], dtype=object)

# %%
len(user_list)
# Out:
# 36950

# %%
year_range=range(2018, 2020)
# user_parse(user_list[4:5], year_range)
user_parse(user_list[30:60], year_range)
# Out:
# All btch 720 are started
# Exception in thread Thread-1169:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-905:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1011:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1108:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1040:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1350:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1351:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1096:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1463:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-975:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1059:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-997:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-876:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1104:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-885:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-993:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1470:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1526:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1284:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1478:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
# Exception in thread Thread-1051:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1202:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-967:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1140:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-990:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-897:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-979:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-954:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1256:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1154:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1395:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1179:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-938:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1370:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1278:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1189:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-986:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1123:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1581:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
# Exception in thread Thread-1134:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1563:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-898:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1483:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1151:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1515:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-923:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-987:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1253:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1323:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1346:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1113:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-937:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1504:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1426:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1534:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1124:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-880:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1571:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1553:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
# Exception in thread Thread-1348:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1060:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1551:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1459:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1337:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1211:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1490:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-910:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1580:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1260:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1322:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1301:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-915:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-891:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1168:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1372:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1198:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-896:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1015:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
# Exception in thread Thread-1371:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1194:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1175:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1233:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1494:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1299:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1160:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1213:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1125:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1171:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1385:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1418:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-920:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1429:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-906:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1383:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1101:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1538:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1074:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1379:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1329:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
# Exception in thread Thread-1214:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1207:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1136:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1445:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1588:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1082:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1411:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
# ...
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-888:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1200:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1199:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1098:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1294:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-913:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1035:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1072:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1517:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1010:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-968:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1099:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1212:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1251:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1191:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1274:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
# Exception in thread Thread-1320:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1540:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-992:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1531:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1088:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1394:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-941:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1586:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1557:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1488:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1500:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1291:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1409:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1454:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1009:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1084:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1330:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1539:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment
#
# Exception in thread Thread-1132:
# Traceback (most recent call last):
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/roman/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-226-91bda369dd34>", line 97, in get_btch
#     return multidata
# UnboundLocalError: local variable 'multidata' referenced before assignment

# %%
get_api_data_to_str('000evgen', '2018', '01')
# Out:
# ('{"games":[]}', 200)

# %%
# %%time
# df=read_files('source/')
df=pd.read_csv('source_old/10net_2018_08_2019-08-11 20:38:18.csv')
df['date'] = df['date'].astype('datetime64[ns]')
# Out:
# CPU times: user 10.9 ms, sys: 0 ns, total: 10.9 ms
# Wall time: 12.2 ms

# %%
len(df)
# Out:
# 95

# %%
df.sample(6)
# Out:
#     Unnamed: 0  rules time_class time_control  rated  game   result  \
# 23           0  chess      blitz        180+2   True     1      0-1
# 76           0  chess      blitz        180+2   True     1      1-0
# 18           0  chess      blitz        180+2   True     1      0-1
# 79           0  chess      blitz        180+2   True     1      1-0
# 67           0  chess      blitz        180+2   True     1      0-1
# 84           0  chess      blitz        180+2   True     1  1/2-1/2
#
#          date      time  period white.username     black.username  \
# 23 2018-08-05  13:59:01  2018-8       BenMuhit              10net
# 76 2018-08-17  18:57:27  2018-8          10net            aleks80
# 18 2018-08-04  14:58:48  2018-8          pyrta              10net
# 79 2018-08-17  21:24:13  2018-8          10net  CandidateMaster20
# 67 2018-08-17  00:44:06  2018-8   mapanganibII              10net
# 84 2018-08-20  20:44:32  2018-8          10net   PawnEatingZombie
#
#     white.rating  black.rating white.result black.result  white.score  \
# 23          2052          1988     resigned          win          0.0
# 76          2080          2109          win      timeout          1.0
# 18          1903          1928     resigned          win          0.0
# 79          2096          1955          win   checkmated          1.0
# 67          2029          2079      timeout          win          0.0
# 84          2117          2138       agreed       agreed          0.5
#
#     black.score  white_elo_forecast  black_elo_forecast  eco  \
# 23          1.0            0.591076            0.408924  D30
# 76          0.0            0.458362            0.541638  E76
# 18          1.0            0.464084            0.535916  A40
# 79          0.0            0.692463            0.307537  D85
# 67          1.0            0.428537            0.571463  D30
# 84          0.5            0.469815            0.530185  D31
#
#                                                                                       eco_url  \
# 23                                  https://www.chess.com/openings/D30-Queens-Gambit-Declined
# 76            https://www.chess.com/openings/E76-Kings-Indian-Defense-Four-Pawns-Dynamic-Line
# 18               https://www.chess.com/openings/A40-Queens-Pawn-Opening-Horwitz-Defense-2.Bf4
# 79             https://www.chess.com/openings/D85-Gruenfeld-Defense-Exchange-Kemeri-Variation
# 67                                  https://www.chess.com/openings/D30-Queens-Gambit-Declined
# 84  https://www.chess.com/openings/D31-Queens-Gambit-Declined-Queens-Knight-Variation-3...Bb4
#
#                                       game_url  \
# 23  https://www.chess.com/live/game/2985840136
# 76  https://www.chess.com/live/game/3012925085
# 18  https://www.chess.com/live/game/2983830706
# 79  https://www.chess.com/live/game/3013198698
# 67  https://www.chess.com/live/game/3011253288
# 84  https://www.chess.com/live/game/3019747124
#
#                                         white_url  \
# 23      https://api.chess.com/pub/player/benmuhit
# 76         https://api.chess.com/pub/player/10net
# 18         https://api.chess.com/pub/player/pyrta
# 79         https://api.chess.com/pub/player/10net
# 67  https://api.chess.com/pub/player/mapanganibii
# 84         https://api.chess.com/pub/player/10net
#
#                                              black_url
# 23              https://api.chess.com/pub/player/10net
# 76            https://api.chess.com/pub/player/aleks80
# 18              https://api.chess.com/pub/player/10net
# 79  https://api.chess.com/pub/player/candidatemaster20
# 67              https://api.chess.com/pub/player/10net
# 84   https://api.chess.com/pub/player/pawneatingzombie

# %%
df['white.username'].value_counts().index[0]
# Out:
# '10net'

# %%
df['date'].value_counts().index[0].strftime("%m")
# Out:
# '08'

# %%
a
# Out:
# Timestamp('2018-08-17 00:00:00')

# %%
from datetime import datetime
tstr=a.strftime("%Y")

# %%
tstr
# Out:
# '2018'

# %%
df['date'].value_counts().index[0][5:7]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-1a06f39e18f2> in <module>
# ----> 1 df['date'].value_counts().index[0][5:7]
#
# TypeError: 'Timestamp' object is not subscriptable

# %%
log_df=pd.read_csv('log.csv', header=None)
log_df.columns=['time', 'proc', 'params']
log_df['line']=1

# %%
len(log_df)
# Out:
# 132

# %%
log_df.sample(3)
# Out:
#                    time             proc  \
# 83  2019-08-25 01:27:24   api_call_error
# 98  2019-08-25 01:27:26  api_call_sucess
# 20  2019-08-25 01:27:23   api_call_error
#
#                                                                                                                                                         params  \
# 83  {"player": "Rosolimo", "year": "2019", "month": "12", "error_code": 404, "error_message": "{\"message\":\"Date cannot be set in the future\",\"code\":0}"}
# 98                                                                                                       {"player": "Rosolimo", "year": "2019", "month": "05"}
# 20  {"player": "sever043", "year": "2019", "month": "12", "error_code": 404, "error_message": "{\"message\":\"Date cannot be set in the future\",\"code\":0}"}
#
#     line
# 83     1
# 98     1
# 20     1

# %%
log_df.groupby('proc').sum()
# Out:
#                  line
# proc
# api_call_error     36
# api_call_sucess    72
# btch_finished      24

# %%
import json
import ast
log_suc=log_df[log_df['proc']=='api_call_sucess'].reset_index()
log_suc['params']=log_suc['params'].apply(lambda x: ast.literal_eval(x))

params=pd.io.json.json_normalize(log_suc['params'])
log_suc=pd.concat([log_suc, params], axis=1)
log_suc=log_suc[pd.isnull(log_suc['time'])==0]
log_suc=log_suc.drop(columns='params')

log_err=log_df[log_df['proc']=='api_call_error'].reset_index()
log_err['params']=log_err['params'].apply(lambda x: ast.literal_eval(x))

params=pd.io.json.json_normalize(log_err['params'])
log_err=pd.concat([log_err, params], axis=1)
log_err=log_err[pd.isnull(log_err['time'])==0]
log_err=log_err.drop(columns='params')

# %%
len(log_err)
# Out:
# 36

# %%
log_err
# Out:
#     index                 time            proc  line  error_code  \
# 0       2  2019-08-25 00:40:48  api_call_error     1         404
# 1       8  2019-08-25 00:40:48  api_call_error     1         404
# 2       9  2019-08-25 00:40:48  api_call_error     1         404
# 3      13  2019-08-25 00:40:48  api_call_error     1         404
# 4      16  2019-08-25 00:40:48  api_call_error     1         404
# 5      18  2019-08-25 00:40:48  api_call_error     1         404
# 6      22  2019-08-25 00:40:48  api_call_error     1         404
# 7      26  2019-08-25 00:40:48  api_call_error     1         404
# 8      31  2019-08-25 00:40:48  api_call_error     1         404
# 9      33  2019-08-25 00:40:48  api_call_error     1         404
# 10     34  2019-08-25 00:40:48  api_call_error     1         404
# 11     36  2019-08-25 00:40:48  api_call_error     1         404
# 12     38  2019-08-25 00:40:48  api_call_error     1         404
# 13     40  2019-08-25 00:40:48  api_call_error     1         404
# 14     44  2019-08-25 00:40:48  api_call_error     1         404
# 15     49  2019-08-25 00:40:48  api_call_error     1         404
# 16     51  2019-08-25 00:40:48  api_call_error     1         404
# 17     52  2019-08-25 00:40:49  api_call_error     1         404
# 18     54  2019-08-25 00:40:49  api_call_error     1         404
# 19     55  2019-08-25 00:40:49  api_call_error     1         404
# 20     56  2019-08-25 00:40:49  api_call_error     1         404
# 21     59  2019-08-25 00:40:49  api_call_error     1         404
# 22     64  2019-08-25 00:40:49  api_call_error     1         404
# 23     65  2019-08-25 00:40:49  api_call_error     1         404
# 24     67  2019-08-25 00:40:49  api_call_error     1         404
# 25     69  2019-08-25 00:40:49  api_call_error     1         404
# 26     73  2019-08-25 00:40:49  api_call_error     1         404
# 27     77  2019-08-25 00:40:49  api_call_error     1         404
# 28     81  2019-08-25 00:40:49  api_call_error     1         404
# 29     83  2019-08-25 00:40:49  api_call_error     1         404
# 30     89  2019-08-25 00:40:50  api_call_error     1         404
# 31     91  2019-08-25 00:40:49  api_call_error     1         404
# 32     98  2019-08-25 00:40:50  api_call_error     1         404
# 33    100  2019-08-25 00:40:50  api_call_error     1         404
# 34    101  2019-08-25 00:40:50  api_call_error     1         404
# 35    102  2019-08-25 00:40:50  api_call_error     1         404
#
#                                               error_message month      player  \
# 0   {"message":"Date cannot be set in the future","code":0}    09  andreyvict
# 1   {"message":"Date cannot be set in the future","code":0}    11  andreyvict
# 2   {"message":"Date cannot be set in the future","code":0}    10    sever043
# 3   {"message":"Date cannot be set in the future","code":0}    09    sever043
# 4   {"message":"Date cannot be set in the future","code":0}    10  andreyvict
# 5   {"message":"Date cannot be set in the future","code":0}    12    sever043
# 6   {"message":"Date cannot be set in the future","code":0}    11  andreyvict
# 7   {"message":"Date cannot be set in the future","code":0}    09  andreyvict
# 8   {"message":"Date cannot be set in the future","code":0}    10  andreyvict
# 9   {"message":"Date cannot be set in the future","code":0}    12    sever043
# 10  {"message":"Date cannot be set in the future","code":0}    10    sever043
# 11  {"message":"Date cannot be set in the future","code":0}    12  andreyvict
# 12  {"message":"Date cannot be set in the future","code":0}    11    sever043
# 13  {"message":"Date cannot be set in the future","code":0}    09    sever043
# 14  {"message":"Date cannot be set in the future","code":0}    09    Rosolimo
# 15  {"message":"Date cannot be set in the future","code":0}    11  andreyvict
# 16  {"message":"Date cannot be set in the future","code":0}    12    Rosolimo
# 17  {"message":"Date cannot be set in the future","code":0}    09  andreyvict
# 18  {"message":"Date cannot be set in the future","code":0}    11    Rosolimo
# 19  {"message":"Date cannot be set in the future","code":0}    12    sever043
# 20  {"message":"Date cannot be set in the future","code":0}    10  andreyvict
# 21  {"message":"Date cannot be set in the future","code":0}    09    sever043
# 22  {"message":"Date cannot be set in the future","code":0}    10    Rosolimo
# 23  {"message":"Date cannot be set in the future","code":0}    12  andreyvict
# 24  {"message":"Date cannot be set in the future","code":0}    10    sever043
# 25  {"message":"Date cannot be set in the future","code":0}    09    Rosolimo
# 26  {"message":"Date cannot be set in the future","code":0}    11    Rosolimo
# 27  {"message":"Date cannot be set in the future","code":0}    12  andreyvict
# 28  {"message":"Date cannot be set in the future","code":0}    11    sever043
# 29  {"message":"Date cannot be set in the future","code":0}    12    Rosolimo
# 30  {"message":"Date cannot be set in the future","code":0}    10    Rosolimo
# 31  {"message":"Date cannot be set in the future","code":0}    09    Rosolimo
# 32  {"message":"Date cannot be set in the future","code":0}    11    Rosolimo
# 33  {"message":"Date cannot be set in the future","code":0}    10    Rosolimo
# 34  {"message":"Date cannot be set in the future","code":0}    11    sever043
# 35  {"message":"Date cannot be set in the future","code":0}    12    Rosolimo
#
#     year
# 0   2019
# 1   2019
# 2   2019
# 3   2019
# 4   2019
# 5   2019
# 6   2019
# 7   2019
# 8   2019
# 9   2019
# 10  2019
# 11  2019
# 12  2019
# 13  2019
# 14  2019
# 15  2019
# 16  2019
# 17  2019
# 18  2019
# 19  2019
# 20  2019
# 21  2019
# 22  2019
# 23  2019
# 24  2019
# 25  2019
# 26  2019
# 27  2019
# 28  2019
# 29  2019
# 30  2019
# 31  2019
# 32  2019
# 33  2019
# 34  2019
# 35  2019

# %%
ds=learn_prepair(df, 'Rosolimo')
#ds=learn_prepair(df, 'sever043')

# %%
ds.sample(3)
# Out:
#      Unnamed: 0  rules time_class time_control  rated  game result       date  \
# 57            0  chess      blitz          300   True     1    1-0 2016-09-16
# 14            0  chess      blitz        180+2   True     1    1-0 2017-04-05
# 209           0  chess      blitz          300   True     1    1-0 2013-10-24
#
#          time   period white.username black.username  white.rating  \
# 57   19:53:50   2016-9        buzanin       Rosolimo          1608
# 14   18:17:56   2017-4  zingarobarone       Rosolimo          1658
# 209  12:41:27  2013-10        P4ULIU5       Rosolimo          1529
#
#      black.rating white.result black.result  white.score  black.score  \
# 57           1651          win     resigned          1.0          0.0
# 14           1534          win     resigned          1.0          0.0
# 209          1486          win     resigned          1.0          0.0
#
#      white_elo_forecast  black_elo_forecast  eco  \
# 57             0.438432            0.561568  A00
# 14             0.671241            0.328759  A08
# 209            0.561568            0.438432  D93
#
#                                                                                 eco_url  \
# 57                          https://www.chess.com/openings/A00-Grob-Opening-Grob-Gambit
# 14         https://www.chess.com/openings/A08-Kings-Indian-Attack-French-Variation-4.d4
# 209  https://www.chess.com/openings/D93-Gruenfeld-Defense-Hungarian-Attack-5...O-O-6.e3
#
#                                        game_url  \
# 57   https://www.chess.com/live/game/1732040676
# 14   https://www.chess.com/live/game/2034406588
# 209   https://www.chess.com/live/game/629463175
#
#                                           white_url  \
# 57         https://api.chess.com/pub/player/buzanin
# 14   https://api.chess.com/pub/player/zingarobarone
# 209        https://api.chess.com/pub/player/p4uliu5
#
#                                      black_url target_user  score  rating  \
# 57   https://api.chess.com/pub/player/rosolimo    Rosolimo    0.0    1651
# 14   https://api.chess.com/pub/player/rosolimo    Rosolimo    0.0    1534
# 209  https://api.chess.com/pub/player/rosolimo    Rosolimo    0.0    1486
#
#      opponent_rating  base_elo_forec color  year  month
# 57              1608        0.561568     b  2016      9
# 14              1658        0.328759     b  2017      4
# 209             1529        0.438432     b  2013     10

# %%
len(ds)
# Out:
# 11504

# %%
ds.to_csv('data/cur_user.csv')

# %%
ds.groupby(['year', 'month']).sum()[['game', 'score']]#.plot()
# Out:
#             game  score
# year month
# 2012 9        95   55.0
# 2013 9       215  105.5
#      10      284  137.5
#      11      287  146.0
#      12      384  183.5
# 2014 1       355  182.5
#      2       294  132.5
#      3       262  127.0
#      4       173   85.5
#      5       202   89.5
#      6       182   89.0
#      7       222  112.0
#      8       308  151.0
#      9       149   70.5
#      10       88   48.0
#      11      193   88.0
#      12      209  103.0
# 2015 1       147   72.0
#      2       168   80.0
#      3       189   96.0
#      4       191   91.0
#      5       222  106.0
#      6        99   52.5
#      7       349  172.5
#      8       192   89.0
#      9       258  119.0
#      10      181   93.0
#      11      185   87.0
#      12      250  126.0
# 2016 1       247  117.0
#      2       234  114.5
#      3       109   49.0
#      4       136   71.0
#      5       130   62.5
#      6        10    4.0
#      7       113   58.0
#      8       183   92.0
#      9       114   50.5
#      10      207  104.0
#      11      116   52.0
#      12      186   96.5
# 2017 1       158   82.0
#      2        62   34.5
#      3        94   41.5
#      4       201  102.5
#      5        56   24.5
#      6        55   27.5
#      7        84   45.5
#      8        88   49.0
#      9        77   44.5
#      10       76   36.0
#      11       16   11.0
#      12       32   17.0
# 2018 1        54   29.0
#      2        33   18.5
#      3        80   42.0
#      4        99   51.5
#      5       189   99.0
#      6       194  103.0
#      7       124   57.5
#      8       128   64.0
#      9       177   90.0
#      10      177   84.0
#      11      164   85.0
#      12      252  122.5
# 2019 1       143   67.0
#      2       114   55.5
#      3       203  107.5
#      4        90   39.0
#      5        40   19.5
#      6        34   17.0
#      7        45   20.5
#      8        47   28.0

# %%
# tst=get_api_data_to_str('Rosolimo', '2015', '11')
